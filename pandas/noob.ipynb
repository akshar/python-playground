# %%
import pandas as pd;

# %%
df = pd.read_json("http://pythonhow.com/supermarkets.json")

# %%
df
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %% [markdown]
#     - Label based indexing
#     - Position based indexing

# %%
df = df.set_index("Address")

# %%
df.loc["3995 23rd St":,"Country":"ID"]    #Label indexing
# Out:
#                 Country  Employees  ID
# Address
# 3995 23rd St        USA         10   4
# 1056 Sanchez St     USA         12   5
# 551 Alvarado St     USA         20   6

# %%
df
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df.iloc[1:3,2:4]   # postion based: pass indices for rows & cols
# Out:
#                 Employees  ID
# Address
# 735 Dolores St         15   2
# 332 Hill St            25   3

# %%
df.iloc[:,2:4] # all rows
# Out:
#                  Employees  ID
# Address
# 3666 21st St             8   1
# 735 Dolores St          15   2
# 332 Hill St             25   3
# 3995 23rd St            10   4
# 1056 Sanchez St         12   5
# 551 Alvarado St         20   6

# %%
df.iloc[3,1:3] # row with index 3 and cols from 1 to 3
# Out:
# Country      USA
# Employees     10
# Name: 3995 23rd St, dtype: object

# %%
df.drop("City",1) # 1 = drop columns
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 3666 21st St        USA          8   1      Madeira          CA 94114
# 735 Dolores St      USA         15   2  Bready Shop          CA 94119
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California
# 551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df.drop("332 Hill St",0)  # drop row with label , 0= drop row
# Out:
#                           City Country  Employees  ID         Name       State
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira    CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop    CA 94119
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley    CA 94114

# %%
df.drop(df.index[0:3], 0) # drop rows based on index
# Out:
#                           City Country  Employees  ID        Name       State
# Address
# 3995 23rd St     San Francisco     USA         10   4  Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5     Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6  Richvalley    CA 94114

# %%
df.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df.drop(df.columns[2:3],1) # drop column 2 (employee)
# Out:
#                           City Country  ID         Name             State
# Address
# 3666 21st St     San Francisco     USA   1      Madeira          CA 94114
# 735 Dolores St   San Francisco     USA   2  Bready Shop          CA 94119
# 332 Hill St      San Francisco     USA   3  Super River  California 94114
# 3995 23rd St     San Francisco     USA   4   Ben's Shop          CA 94114
# 1056 Sanchez St  San Francisco     USA   5      Sanchez        California
# 551 Alvarado St  San Francisco     USA   6   Richvalley          CA 94114

# %%
df.shape
# Out:
# (6, 6)

# %%
df
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df.shape[0] * ["foo"]
# Out:
# ['foo', 'foo', 'foo', 'foo', 'foo', 'foo']

# %%
df["continent"] = df.shape[0] * ["foo"]

# %%
df
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State continent
# Address
# 3666 21st St             CA 94114       foo
# 735 Dolores St           CA 94119       foo
# 332 Hill St      California 94114       foo
# 3995 23rd St             CA 94114       foo
# 1056 Sanchez St        California       foo
# 551 Alvarado St          CA 94114       foo

# %%
df["continent"] = df["Country"] + " " + "foo"  # Add colum

# %%
df
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State continent
# Address
# 3666 21st St             CA 94114   USA foo
# 735 Dolores St           CA 94119   USA foo
# 332 Hill St      California 94114   USA foo
# 3995 23rd St             CA 94114   USA foo
# 1056 Sanchez St        California   USA foo
# 551 Alvarado St          CA 94114   USA foo

# %%
df_t = df.T   # Add New row

# %%
df_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# Country              USA            USA               USA            USA
# Employees              8             15                25             10
# ID                     1              2                 3              4
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# State           CA 94114       CA 94119  California 94114       CA 94114
# continent        USA foo        USA foo           USA foo        USA foo
#
# Address   1056 Sanchez St 551 Alvarado St
# City        San Francisco   San Francisco
# Country               USA             USA
# Employees              12              20
# ID                      5               6
# Name              Sanchez      Richvalley
# State          California        CA 94114
# continent         USA foo         USA foo

# %%
df_t["my_address"] = ["my city", "mycountry", "foo employees", "foo id","foo name", "foo state", "foo continent"]

# %%
df_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# Country              USA            USA               USA            USA
# Employees              8             15                25             10
# ID                     1              2                 3              4
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# State           CA 94114       CA 94119  California 94114       CA 94114
# continent        USA foo        USA foo           USA foo        USA foo
#
# Address   1056 Sanchez St 551 Alvarado St     my_address
# City        San Francisco   San Francisco        my city
# Country               USA             USA      mycountry
# Employees              12              20  foo employees
# ID                      5               6         foo id
# Name              Sanchez      Richvalley       foo name
# ...

# %%
df = df_t.T

# %%
df
# Out:
#                           City    Country      Employees      ID         Name  \
# Address
# 3666 21st St     San Francisco        USA              8       1      Madeira
# 735 Dolores St   San Francisco        USA             15       2  Bready Shop
# 332 Hill St      San Francisco        USA             25       3  Super River
# 3995 23rd St     San Francisco        USA             10       4   Ben's Shop
# 1056 Sanchez St  San Francisco        USA             12       5      Sanchez
# 551 Alvarado St  San Francisco        USA             20       6   Richvalley
# my_address             my city  mycountry  foo employees  foo id     foo name
#
#                             State      continent
# Address
# 3666 21st St             CA 94114        USA foo
# 735 Dolores St           CA 94119        USA foo
# 332 Hill St      California 94114        USA foo
# 3995 23rd St             CA 94114        USA foo
# 1056 Sanchez St        California        USA foo
# ...
