# %%
import pandas

# %%
df = pandas.read_csv("/Users/akshar/Downloads/www-womaura-com-2017-10-04T05-37-06.701922-all.xml.csv")

# %%
df
# Out:
#     disqus              xmlns                           xmlns:dsq  \
# 0      NaN  http://disqus.com  http://disqus.com/disqus-internals
# 1      NaN                NaN                                 NaN
# 2      NaN                NaN                                 NaN
# 3      NaN                NaN                                 NaN
# 4      NaN                NaN                                 NaN
# 5      NaN                NaN                                 NaN
# 6      NaN                NaN                                 NaN
# 7      NaN                NaN                                 NaN
# 8      NaN                NaN                                 NaN
# 9      NaN                NaN                                 NaN
# 10     NaN                NaN                                 NaN
# 11     NaN                NaN                                 NaN
# 12     NaN                NaN                                 NaN
# ...
